# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# ## Introduction about Data:

# %% [markdown]
# **The goal of this project is to detect the Fraud cases in Credit Card transactions**

# %% [markdown]
# This dataset is Highly imbalanced. Only 492 fraud cases found in 289802 transacations.

# %% [markdown]
# ### Import Necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read Data:

# %%
df = pd.read_csv('creditcard.csv/creditcard.csv')

# %% [markdown]
# #### Show top 5 records

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# #### Show data Shape

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ### Dataset Info:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ### Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# #### There are no missing values in the dataset

# %% [markdown]
# ### Descriptive Statistics:

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %% [markdown]
# ### Data Exploration:

# %% [markdown]
# #### Checking the imbalance of target variable

# %%
plt.figure(figsize=(12,6))
size = df['Class'].value_counts()
labels = 'Not Fraud', 'Fraud'
color = ['green', 'red']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Fraud Class', fontsize = 20)
plt.axis('off')
plt.show()

# %% [markdown]
# #### The data of target variable is highly imbalanced

# %%
Not_Fraud = df[df['Class']==0]
Fraud = df[df['Class']==1]

# %%
Not_Fraud.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
Fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
Fraud.Time.describe()
# Out:
# count       492.000000
# mean      80746.806911
# std       47835.365138
# min         406.000000
# 25%       41241.500000
# 50%       75568.500000
# 75%      128483.000000
# max      170348.000000
# Name: Time, dtype: float64

# %%
Not_Fraud.Time.describe()
# Out:
# count    284315.000000
# mean      94838.202258
# std       47484.015786
# min           0.000000
# 25%       54230.000000
# 50%       84711.000000
# 75%      139333.000000
# max      172792.000000
# Name: Time, dtype: float64

# %%
plt.figure(figsize=(8,4))
group_labels = ['Not Fraud', 'Fraud']
sns.barplot(x='Time', data=df, hue='Class')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')
ax1.scatter(Fraud.Time, Fraud.Amount)
ax1.set_title('Fraud')
ax2.scatter(Not_Fraud.Time, Not_Fraud.Amount)
ax2.set_title('Not Fraud')
plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
plt.figure(figsize=(28,14))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# - There are some features which are negatively correlated to Target feature and some are nearly no correlation and some are positively correlated.
# - No correlation among V1-V28 features.
# - 'Amount' has positive correlation with fetaures V7, V20 and negative correlation with V2, V5
# - 'Time' has negative correlation with fetaures V3, V11, V25
# - Class has negative correlation with V17, V16, V14, V12, V10, V7, V3 and some positive correlation with V11, V4, V2

# %% [markdown]
# ### Checking Outliers:

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
plt.subplots(1,5,figsize=(16,5))
plt.subplot(151)
sns.boxplot(df['Time'],color='skyblue')
plt.subplot(152)
sns.boxplot(df['V1'],color='hotpink')
plt.subplot(153)
sns.boxplot(df['V2'],color='yellow')
plt.subplot(154)
sns.boxplot(df['V3'],color='lightgreen')
plt.subplot(155)
sns.boxplot(df['V4'],color='red')
plt.show()

# %%
plt.subplots(1,5,figsize=(16,5))
plt.subplot(151)
sns.boxplot(df['V5'],color='skyblue')
plt.subplot(152)
sns.boxplot(df['V6'],color='hotpink')
plt.subplot(153)
sns.boxplot(df['V7'],color='yellow')
plt.subplot(154)
sns.boxplot(df['V8'],color='lightgreen')
plt.subplot(155)
sns.boxplot(df['V9'],color='red')
plt.show()

# %%
plt.subplots(1,5,figsize=(16,5))
plt.subplot(151)
sns.boxplot(df['V10'],color='skyblue')
plt.subplot(152)
sns.boxplot(df['V11'],color='hotpink')
plt.subplot(153)
sns.boxplot(df['V12'],color='yellow')
plt.subplot(154)
sns.boxplot(df['V13'],color='lightgreen')
plt.subplot(155)
sns.boxplot(df['V14'],color='red')
plt.show()

# %%
plt.subplots(1,5,figsize=(16,5))
plt.subplot(151)
sns.boxplot(df['V15'],color='skyblue')
plt.subplot(152)
sns.boxplot(df['V16'],color='hotpink')
plt.subplot(153)
sns.boxplot(df['V17'],color='yellow')
plt.subplot(154)
sns.boxplot(df['V18'],color='lightgreen')
plt.subplot(155)
sns.boxplot(df['V19'],color='red')
plt.show()

# %%
plt.subplots(1,5,figsize=(16,5))
plt.subplot(151)
sns.boxplot(df['V20'],color='skyblue')
plt.subplot(152)
sns.boxplot(df['V21'],color='hotpink')
plt.subplot(153)
sns.boxplot(df['V22'],color='yellow')
plt.subplot(154)
sns.boxplot(df['V23'],color='lightgreen')
plt.subplot(155)
sns.boxplot(df['V24'],color='red')
plt.show()

# %%
plt.subplots(1,5,figsize=(16,5))
plt.subplot(151)
sns.boxplot(df['V25'],color='skyblue')
plt.subplot(152)
sns.boxplot(df['V26'],color='hotpink')
plt.subplot(153)
sns.boxplot(df['V27'],color='yellow')
plt.subplot(154)
sns.boxplot(df['V28'],color='lightgreen')
plt.subplot(155)
sns.boxplot(df['Amount'],color='red')
plt.show()

# %% [markdown]
# - It is observered that all input columns has Outliers
# - Only 'Time' column has no outliers
#
# **So it is best to choose models which are robust to Outliers**
